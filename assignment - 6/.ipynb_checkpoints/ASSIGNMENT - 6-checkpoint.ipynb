# %% [markdown]
# # Assignment-6

# %%
import pandas as pd

# %%
d1={'Id':['A1','A2','A3','A4','A5'],'Age':[27,24,22,32,28],'Name':['Vivek','Rahul','Gaurav','Ankit','vishak']}
d2={'Id':['A1','A2','A3','A4'],'Address':['Delhi','Gurgoan','Noida','Pune'],'Qualification':['Btech','B.A','BcomB','B.Hons']}

# %%
df1=pd.DataFrame(d1)
df2=pd.DataFrame(d2)

# %%
#Case 1. merging data on common columns 'Id'
#Inner Join
pd.merge(df1,df2)
# Out:
#    Id  Age    Name  Address Qualification
# 0  A1   27   Vivek    Delhi         Btech
# 1  A2   24   Rahul  Gurgoan           B.A
# 2  A3   22  Gaurav    Noida         BcomB
# 3  A4   32   Ankit     Pune        B.Hons

# %%
pd.merge (df1, df2, how='inner')
# Out:
#    Id  Age    Name  Address Qualification
# 0  A1   27   Vivek    Delhi         Btech
# 1  A2   24   Rahul  Gurgoan           B.A
# 2  A3   22  Gaurav    Noida         BcomB
# 3  A4   32   Ankit     Pune        B.Hons

# %%
#Left Join
pd.merge (df1, df2,how='left')
# Out:
#    Id  Age    Name  Address Qualification
# 0  A1   27   Vivek    Delhi         Btech
# 1  A2   24   Rahul  Gurgoan           B.A
# 2  A3   22  Gaurav    Noida         BcomB
# 3  A4   32   Ankit     Pune        B.Hons
# 4  A5   28  vishak      NaN           NaN

# %%
#Right Join
pd.merge (df1, df2,how='right')
# Out:
#    Id  Age    Name  Address Qualification
# 0  A1   27   Vivek    Delhi         Btech
# 1  A2   24   Rahul  Gurgoan           B.A
# 2  A3   22  Gaurav    Noida         BcomB
# 3  A4   32   Ankit     Pune        B.Hons

# %%
#outer join
pd.merge (df1, df2,how='outer')
# Out:
#    Id  Age    Name  Address Qualification
# 0  A1   27   Vivek    Delhi         Btech
# 1  A2   24   Rahul  Gurgoan           B.A
# 2  A3   22  Gaurav    Noida         BcomB
# 3  A4   32   Ankit     Pune        B.Hons
# 4  A5   28  vishak      NaN           NaN

# %%
d1={'Id':['A1','A2','A3','A4','A5'],'Age':[27,24,22,32,28],'Name':['Vivek','Rahul','Gaurav','Ankit','vishak']}
d2={'ID':['A1','A2','A3','A4'],'Address':['Delhi','Gurgoan','Noida','Pune'],'Qualification':['Btech','B.A','BcomB','B.Hons']}

# %%
df1=pd.DataFrame (d1)
df2=pd. DataFrame (d2)

# %%
pd.merge(df1, df2)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-28-bf676d91be05> in <module>
# ----> 1 pd.merge(df1, df2)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     643             warnings.warn(msg, UserWarning)
#     644
# --> 645         self._validate_specification()
#     646
#     647         # note this function has side effects
#
# ...

# %%
 #df1 key column 'Id'
#df2 key column 'ID'

# %%
pd.merge(df1,df2,left_on='Id',right_on='ID',how='left')
# Out:
#    Id  Age    Name   ID  Address Qualification
# 0  A1   27   Vivek   A1    Delhi         Btech
# 1  A2   24   Rahul   A2  Gurgoan           B.A
# 2  A3   22  Gaurav   A3    Noida         BcomB
# 3  A4   32   Ankit   A4     Pune        B.Hons
# 4  A5   28  vishak  NaN      NaN           NaN

# %% [markdown]
# # ii) Illustrate the usage of join to combine data frames

# %%
import pandas as pd
df1 = pd. DataFrame ({ 'key': ['KO', 'K1', 'K5', 'K3', 'K4', 'K2'],'A': ['A0', 'A1','A5','A3','A4','A2']})
df2= pd. DataFrame ({ 'key': ['KO', 'K1', 'K2'],'B': ['BO', 'B1', 'B2']})

# %% [markdown]
# # Case 1:Join on indexes

# %%
#default nature of pandas join is left outer join
df1.join (df2, lsuffix=' _l', rsuffix=' _r')
# Out:
#   key _l   A key _r    B
# 0     KO  A0     KO   BO
# 1     K1  A1     K1   B1
# 2     K5  A5     K2   B2
# 3     K3  A3    NaN  NaN
# 4     K4  A4    NaN  NaN
# 5     K2  A2    NaN  NaN

# %% [markdown]
# # Create two dataframes with different index values.

# %%
df1 = pd. DataFrame ({ 'key': ['KO', 'K1', 'K5', 'K3', 'K4', 'K2'],'A': ['A0', 'A1','A5','A3','A4','A2']})
index= [0,1,2,3,4,5]
df2 = pd. DataFrame ({ 'key': ['KO', 'K1', 'K2'],'B': ['B0', 'B1', 'B2']},
index= [6,7,8])
#df1 is left DF and df2 is right DF

# %%
#inner join
df1.join (df2,lsuffix=' _l', rsuffix=' _r',how='inner')#########################
# Out:
# Empty DataFrame
# Columns: [key _l, A, key _r, B]
# Index: []

# %%
#outer join
df1.join (df2,lsuffix='_l', rsuffix='_r', how='outer')
# Out:
#   key_l    A key_r    B
# 0    KO   A0   NaN  NaN
# 1    K1   A1   NaN  NaN
# 2    K5   A5   NaN  NaN
# 3    K3   A3   NaN  NaN
# 4    K4   A4   NaN  NaN
# 5    K2   A2   NaN  NaN
# 6   NaN  NaN    KO   B0
# 7   NaN  NaN    K1   B1
# 8   NaN  NaN    K2   B2

# %%
import pandas as pd
df1=pd.DataFrame({'key1':['K0','K1','K5','K3','K4','K2'],'A':['A0','A1','A5','A3','A4','A2']})
df2=pd.DataFrame({'key2':['K0','K1','K2'],'B':['B0','B1','B2']})
df1=pd.DataFrame({'key1':['K0','K1','K5','K3','K4','K2'],'A':['A0','A1','A5','A3','A4','A2']})
df2=pd.DataFrame({'key2':['K0','K1','K2'],'B':['B0','B1','B2']})

# %%
#join on data frame column
df1.set_index('key1').join(df2.set_index ('key2'))
# Out:
#        A    B
# key1
# K0    A0   B0
# K1    A1   B1
# K5    A5  NaN
# K3    A3  NaN
# K4    A4  NaN
# K2    A2   B2

# %% [markdown]
# # iii.Illustrate the use of concat to combine dataframes

# %% [markdown]
# ### Case 1. concat data frames on axis=0, default operation

# %%
import pandas as pd
m1 =pd. DataFrame ({'Name': [ 'Alex', 'Amy', 'Allen', 'Alice', 'Ayoung' ],'subject_id':['sub1','sub2','sub4','sub6','sub5'],
'Marks_scored': [98, 90, 87, 69, 781]},index= [1, 2, 3, 4, 5])
m2 =pd. DataFrame ({'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],'subject_id':['sub2','sub4','sub3','sub6','sub5'],
'Marks_scored': [89, 80, 79,97,88]},index= [ 4, 5, 6, 7, 8])
pd.concat([m1, m2])
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5           781
# 4   Billy       sub2            89
# 5   Brian       sub4            80
# 6    Bran       sub3            79
# 7   Bryce       sub6            97
# 8   Betty       sub5            88

# %% [markdown]
# # Case 2. concat operation on axis=1, horizontal operation

# %%
#axis=1 works as join operation
pd.concat([m1, m2], axis=1) ##########
# Out:
#      Name subject_id  Marks_scored   Name subject_id  Marks_scored
# 1    Alex       sub1          98.0    NaN        NaN           NaN
# 2     Amy       sub2          90.0    NaN        NaN           NaN
# 3   Allen       sub4          87.0    NaN        NaN           NaN
# 4   Alice       sub6          69.0  Billy       sub2          89.0
# 5  Ayoung       sub5         781.0  Brian       sub4          80.0
# 6     NaN        NaN           NaN   Bran       sub3          79.0
# 7     NaN        NaN           NaN  Bryce       sub6          97.0
# 8     NaN        NaN           NaN  Betty       sub5          88.0

# %% [markdown]
# ### Case 3. concat unequal shape data frames

# %%
df1 = pd.DataFrame({'A':[1,2,3],'B':[1,2,3]})
df2= pd.DataFrame({'A': [4, 5]})

# %%
df = pd.concat([df1, df2],ignore_index=True)
df
# Out:
#    A    B
# 0  1  1.0
# 1  2  2.0
# 2  3  3.0
# 3  4  NaN
# 4  5  NaN

# %% [markdown]
# ## iv. append() combine data frames vertically fashion

# %% [markdown]
# Case 1. appending data frames, duplicate index issue

# %%
m1 = pd.DataFrame({
'Name': [ 'Alex', 'Amy', 'Allen', 'Alice', 'Ayoung' ],
'subject_id': ['sub1','sub2', 'sub4','sub6','sub5'],
'Marks_scored': [98, 90, 87, 69, 78]},
index= [1, 2, 3, 4, 5])
m2 = pd.DataFrame({
'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
'subject_id': ['sub2', 'sub4', 'sub3', 'sub6', 'sub5'],
'Marks_scored': [89, 80, 79,97,88]},
index= [1, 2, 3, 4, 5])

# %%
m1.append (m2, verify_integrity=False)
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
#verify_integrity=False is default argument
m1.append (m2)
#output will be similar for both above lines of code
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %% [markdown]
# Case 2. append data frames with unequal shapes

# %%
m1 = pd. DataFrame ({
'Name': [ 'Vivek', 'Vishakha', 'Ash', 'Natalie', 'Ayoung' ],
'subject_id': ['sub1','sub2', 'sub4', 'sub6','sub5'],
'Marks_scored': [98, 90, 87, 69, 78],
'Rank': [1, 3, 6, 20,13]},
index= [1,2,3,4,5])
m2 = pd. DataFrame ({
'Name': ['Barak', 'Wayne', 'Saurav', 'Yuvraj', 'Suresh'],
'subject_id': [ 'sub2', 'sub4', 'sub3','sub6','sub5'],
'Marks_scored': [89, 80, 79, 97,88],},
index= [1,2,3,4,5])

# %%
m1.append(m2)
# Out:
#        Name subject_id  Marks_scored  Rank
# 1     Vivek       sub1            98   1.0
# 2  Vishakha       sub2            90   3.0
# 3       Ash       sub4            87   6.0
# 4   Natalie       sub6            69  20.0
# 5    Ayoung       sub5            78  13.0
# 1     Barak       sub2            89   NaN
# 2     Wayne       sub4            80   NaN
# 3    Saurav       sub3            79   NaN
# 4    Yuvraj       sub6            97   NaN
# 5    Suresh       sub5            88   NaN
