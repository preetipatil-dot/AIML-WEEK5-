# %% [markdown]
# ### Assignment - 3

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## a) Read text file(old car data set)

# %%
cols=['symboling','normalized-losses','make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','wheel-base','length','width','height','curb-weight','engine-type','num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']
data=pd.read_csv("imports-85.data",names=cols)
print(data.shape)
data
# Out:
# (205, 26)
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19    3.40              10.0        102
# 4            136         mpfi  3.19    3.40               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01    3.40              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
data['num-of-doors'].nunique()
# Out:
# 3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
data['normalized-losses'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # b) identify missing values,evaluate missing values,deal with missing valuesnand correct data format

# %%
data=data.replace("?",np.NaN)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
data.isnull().any().any()
# Out:
# True

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#compute the mean of 'normalized-losses'
avg_norm_loss=data['normalized-losses'].astype("float").mean()
avg_norm_loss
# Out:
# 122.0

# %%
#replace missing values by mean
data['normalized-losses'].replace(np.NaN,avg_norm_loss,inplace=True)
data['normalized-losses']
# Out:
# 0      122
# 1      122
# 2      122
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
avg_bore=data['bore'].astype("float").mean()
avg_bore
# Out:
# 3.3297512437810957

# %%
#replace missing values by mean
data['bore'].replace(np.NaN,avg_norm_loss,inplace=True)
data['bore']
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: object

# %%
#compute mean of steoke
avg_stroke=data['stroke'].astype("float").mean(axis=0)
avg_stroke
# Out:
# 3.2554228855721337

# %%
#replace missing values by mean
data['stroke'].replace(np.NaN,avg_norm_loss,inplace=False)
data['stroke']
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: object

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
data['bore'].dtypes
# Out:
# dtype('O')

# %%
avg_horsepower=data['horsepower'].astype("float").mean(axis=0)
avg_horsepower
# Out:
# 104.25615763546799

# %%
data['horsepower'].replace(np.NaN,avg_norm_loss,inplace=True)
data['horsepower']
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
avg_peakrpm=data['peak-rpm'].astype("float").mean()
avg_peakrpm
# Out:
# 5125.369458128079

# %%
data['peak-rpm'].replace(np.NaN,avg_norm_loss,inplace=True)
data['peak-rpm']
# Out:
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peak-rpm, Length: 205, dtype: object

# %%
data['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
#getting the most frequent value
data['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
data['num-of-doors'].replace(np.NaN,'four',inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          3               122  alfa-romero       gas        std          two
# 2          1               122  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
#evaluating the missing  values of 'price' attribute
before_rows=data.shape[0]
data.dropna(subset=['price'],axis=0,inplace=True)
after_rows=data.shape[0]
print("number of dropped rows:{}".format(before_rows-after_rows))
#reset index values
data.reset_index(drop=True,inplace=True)
# Out:
# number of dropped rows:4

# %%
data.shape
# Out:
# (201, 26)

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#convert datatypes to proper format
data[['bore','stroke']]=data[['bore','stroke']].astype('float')
data[['normalized-losses']]==data[['normalized-losses']].astype('int')
data[['price']]==data[['price']].astype("float")
data[['peak-rpm']]=data[['peak-rpm']].astype("float") 
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          3               122  alfa-romero       gas        std          two
# 2          1               122  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111    5000.0       21
# 1         mpfi  3.47    2.68               9.0        111    5000.0       21
# 2         mpfi  2.68    3.47               9.0        154    5000.0       19
# 3         mpfi  3.19    3.40              10.0        102    5500.0       24
# 4         mpfi  3.19    3.40               8.0        115    5500.0       18
#
#    highway-mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# 3           30  13950
# 4           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ## c) Data standarzation

# %%
data['highway-mpg']=235/data['highway-mpg']

# %%
#rename the column name

data.rename(columns={'highway-mpg': 'highway-L/100km'},inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          3               122  alfa-romero       gas        std          two
# 2          1               122  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111    5000.0       21
# 1         mpfi  3.47    2.68               9.0        111    5000.0       21
# 2         mpfi  2.68    3.47               9.0        154    5000.0       19
# 3         mpfi  3.19    3.40              10.0        102    5500.0       24
# 4         mpfi  3.19    3.40               8.0        115    5500.0       18
#
#    highway-L/100km  price
# 0         8.703704  13495
# 1         8.703704  16500
# 2         9.038462  16500
# 3         7.833333  13950
# 4        10.681818  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ## d) Data Normalization (centering/scaling)

# %%
data['length']=data['length']/data['length'].max()
data['width']=data['width']/data['width'].max()
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          3               122  alfa-romero       gas        std          two
# 2          1               122  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111    5000.0       21
# 1         mpfi  3.47    2.68               9.0        111    5000.0       21
# 2         mpfi  2.68    3.47               9.0        154    5000.0       19
# 3         mpfi  3.19    3.40              10.0        102    5500.0       24
# 4         mpfi  3.19    3.40               8.0        115    5500.0       18
#
#    highway-L/100km  price
# 0         8.703704  13495
# 1         8.703704  16500
# 2         9.038462  16500
# 3         7.833333  13950
# 4        10.681818  17450
#
# [5 rows x 26 columns]

# %%
data['height']=data['height']/data['height'].max()
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          3               122  alfa-romero       gas        std          two
# 2          1               122  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111    5000.0       21
# 1         mpfi  3.47    2.68               9.0        111    5000.0       21
# 2         mpfi  2.68    3.47               9.0        154    5000.0       19
# 3         mpfi  3.19    3.40              10.0        102    5500.0       24
# 4         mpfi  3.19    3.40               8.0        115    5500.0       18
#
#    highway-L/100km  price
# 0         8.703704  13495
# 1         8.703704  16500
# 2         9.038462  16500
# 3         7.833333  13950
# 4        10.681818  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# # e) binning

# %%
data['horsepower']=data['horsepower'].astype(int,copy=True)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          3               122  alfa-romero       gas        std          two
# 2          1               122  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111    5000.0       21
# 1         mpfi  3.47    2.68               9.0        111    5000.0       21
# 2         mpfi  2.68    3.47               9.0        154    5000.0       19
# 3         mpfi  3.19    3.40              10.0        102    5500.0       24
# 4         mpfi  3.19    3.40               8.0        115    5500.0       18
#
#    highway-L/100km  price
# 0         8.703704  13495
# 1         8.703704  16500
# 2         9.038462  16500
# 3         7.833333  13950
# 4        10.681818  17450
#
# [5 rows x 26 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(data['horsepower'])
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
#text(0.5,1.0,'horsepower bins')
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins=np.linspace(min(data['horsepower']),max(data['horsepower']),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
gruop_names=['Low','Medium','High']
data['horsepower-binned']=pd.cut(data['horsepower'],bins,labels=gruop_names,include_lowest=True)
data[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          111               Low
# 2          154            Medium
# 3          102               Low
# 4          115               Low
# 5          110               Low
# 6          110               Low
# 7          110               Low
# 8          140            Medium
# 9          101               Low
# 10         101               Low
# 11         121            Medium
# 12         121            Medium
# 13         121            Medium
# 14         182            Medium
# 15         182            Medium
# 16         182            Medium
# 17          48               Low
# 18          70               Low
# 19          70               Low

# %%
data['horsepower-binned'].value_counts()
# %matplotlib inline
 
plt.bar(gruop_names,data['horsepower-binned'].value_counts())
plt.xlabel('horsepower')
plt.ylabel('count')
plt.title('horsepower bins')
#text(0.5,1.0,'horsepower bins')
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# ## f) indicator variable

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
a=(0,1,2)
plt.hist(data['horsepower'],bins=3)
plt.xlabel('horsepower')
plt.ylabel('count')
plt.title('horsepower bins')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
dummy_variable_1=pd.get_dummies(data['fuel-type'])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable_1.rename(columns={'fuel-type-gas':'gas','fuel-type-diesel':'diesel'})
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
data=pd.concat([data,dummy_variable_1],axis=1)
data.drop('fuel-type',axis=1,inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3               122  alfa-romero        std          two
# 1          3               122  alfa-romero        std          two
# 2          1               122  alfa-romero        std          two
# 3          2               164         audi        std         four
# 4          2               164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    stroke  compression-ratio  horsepower peak-rpm city-mpg  highway-L/100km  \
# 0    2.68                9.0         111   5000.0       21         8.703704
# 1    2.68                9.0         111   5000.0       21         8.703704
# 2    3.47                9.0         154   5000.0       19         9.038462
# 3    3.40               10.0         102   5500.0       24         7.833333
# 4    3.40                8.0         115   5500.0       18        10.681818
#
#    price  horsepower-binned  diesel  gas
# 0  13495                Low       0    1
# 1  16500                Low       0    1
# 2  16500             Medium       0    1
# 3  13950                Low       0    1
# 4  17450                Low       0    1
#
# [5 rows x 28 columns]

# %%
dummy_variable_2=pd.get_dummies(data['aspiration'])
dummy_variable_2.rename(columns={'std':'aspiration-std','turbo':'aspiration'} )
dummy_variable_2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
data=pd.concat([data,dummy_variable_2],axis=1)
data.drop('aspiration',axis=1,inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make num-of-doors   body-style  \
# 0          3               122  alfa-romero          two  convertible
# 1          3               122  alfa-romero          two  convertible
# 2          1               122  alfa-romero          two    hatchback
# 3          2               164         audi         four        sedan
# 4          2               164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  \
# 0          rwd           front        88.6  0.811148  0.890278  ...
# 1          rwd           front        88.6  0.811148  0.890278  ...
# 2          rwd           front        94.5  0.822681  0.909722  ...
# 3          fwd           front        99.8  0.848630  0.919444  ...
# 4          4wd           front        99.4  0.848630  0.922222  ...
#
#    horsepower  peak-rpm city-mpg highway-L/100km  price horsepower-binned  \
# 0         111    5000.0       21        8.703704  13495               Low
# 1         111    5000.0       21        8.703704  16500               Low
# 2         154    5000.0       19        9.038462  16500            Medium
# 3         102    5500.0       24        7.833333  13950               Low
# 4         115    5500.0       18       10.681818  17450               Low
#
#    diesel  gas  std  turbo
# 0       0    1    1      0
# 1       0    1    1      0
# 2       0    1    1      0
# 3       0    1    1      0
# 4       0    1    1      0
#
# [5 rows x 29 columns]

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  201.000000  201.000000  201.000000  201.000000  201.000000
# mean     0.840796   98.797015    0.837102    0.915126    0.899108
# std      1.254802    6.066366    0.059213    0.029187    0.040933
# min     -2.000000   86.600000    0.678039    0.837500    0.799331
# 25%      0.000000   94.500000    0.801538    0.890278    0.869565
# 50%      1.000000   97.000000    0.832292    0.909722    0.904682
# 75%      2.000000  102.400000    0.881788    0.925000    0.928094
# max      3.000000  120.900000    1.000000    1.000000    1.000000
#
#        curb-weight  engine-size        bore      stroke  compression-ratio  \
# count   201.000000   201.000000  201.000000  197.000000         201.000000
# mean   2555.666667   126.875622    5.692289    3.256904          10.164279
# std     517.296727    41.546834   16.616706    0.319256           4.004965
# min    1488.000000    61.000000    2.540000    2.070000           7.000000
# 25%    2169.000000    98.000000    3.150000    3.110000           8.600000
# 50%    2414.000000   120.000000    3.310000    3.290000           9.000000
# 75%    2926.000000   141.000000    3.600000    3.410000           9.400000
# max    4066.000000   326.000000  122.000000    4.170000          23.000000
#
#        horsepower     peak-rpm    city-mpg  highway-L/100km      diesel  \
# count  201.000000   201.000000  201.000000       201.000000  201.000000
# mean   103.582090  5067.880597   25.179104         8.044957    0.099502
# std     37.411422   689.686904    6.423220         1.840739    0.300083
# min     48.000000   122.000000   13.000000         4.351852    0.000000
# 25%     70.000000  4800.000000   19.000000         6.911765    0.000000
# 50%     95.000000  5100.000000   24.000000         7.833333    0.000000
# 75%    116.000000  5500.000000   30.000000         9.400000    0.000000
# max    262.000000  6600.000000   49.000000        14.687500    1.000000
#
#               gas         std       turbo
# count  201.000000  201.000000  201.000000
# mean     0.900498    0.820896    0.179104
# std      0.300083    0.384397    0.384397
# min      0.000000    0.000000    0.000000
# 25%      1.000000    1.000000    0.000000
# 50%      1.000000    1.000000    0.000000
# 75%      1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000

# %% [markdown]
# ## g) writing csv file

# %%
data.to_csv("wrangled_data.c")

# %% [markdown]
# Conclusion
# The following concepts are learnt:
#
# 1) Reading text file (old car data set)
#
# 2) Writing csv file
#
# 3) Performing data wrangling
